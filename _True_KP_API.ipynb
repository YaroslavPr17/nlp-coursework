# %%
# !pip install kinopoisk-api-unofficial-client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: kinopoisk-api-unofficial-client in c:\users\yaroslav pristalov\appdata\roaming\python\python39\site-packages (2.2.2)
# Requirement already satisfied: apischema==0.15.6 in c:\users\yaroslav pristalov\appdata\roaming\python\python39\site-packages (from kinopoisk-api-unofficial-client) (0.15.6)
# Requirement already satisfied: requests<=2.26.0 in c:\users\yaroslav pristalov\appdata\roaming\python\python39\site-packages (from kinopoisk-api-unofficial-client) (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\programdata\anaconda3\lib\site-packages (from requests<=2.26.0->kinopoisk-api-unofficial-client) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programdata\anaconda3\lib\site-packages (from requests<=2.26.0->kinopoisk-api-unofficial-client) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\programdata\anaconda3\lib\site-packages (from requests<=2.26.0->kinopoisk-api-unofficial-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\programdata\anaconda3\lib\site-packages (from requests<=2.26.0->kinopoisk-api-unofficial-client) (3.3)

# %%
# from kinopoisk_unofficial.kinopoisk_api_client import KinopoiskApiClient
# from kinopoisk_unofficial.model.filter_country import FilterCountry
# from kinopoisk_unofficial.model.filter_genre import FilterGenre
# from kinopoisk_unofficial.model.filter_order import FilterOrder
# from kinopoisk_unofficial.model.dictonary.film_type import FilmType
# from kinopoisk_unofficial.request.films.film_search_by_filters_request import FilmSearchByFiltersRequest

# api_client = KinopoiskApiClient("56a4f169-32e7-444b-9d6a-a75dd49a122b")

# request = FilmSearchByFiltersRequest()
# request.year_from = 2010
# request.rating_from = 1
# request.rating_to = 10
# request.order = FilterOrder.RATING
# request.add_country(FilterCountry(1, 'США'))
# request.type = FilmType.VIDEO
# request.add_genre(FilterGenre(1, 'боевик'))

# print(request.response_class())

# response = api_client.films.send_film_search_by_filters_request(request)


from kinopoisk_unofficial.kinopoisk_api_client import KinopoiskApiClient
from kinopoisk_unofficial.request.reviews.reviews_request import ReviewsRequest

api_client = KinopoiskApiClient("56a4f169-32e7-444b-9d6a-a75dd49a122b")
request = ReviewsRequest(405609)
response = api_client.reviews.send_reviews_request(request)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Input In [44], in <cell line: 29>()
#      27 api_client = KinopoiskApiClient("56a4f169-32e7-444b-9d6a-a75dd49a122b")
#      28 request = ReviewsRequest(405609)
# ---> 29 response = api_client.reviews.send_reviews_request(request)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\kinopoisk_unofficial\client\reviews_api_client.py:10, in ReviewsApiClient.send_reviews_request(self, request)
#       9 def send_reviews_request(self, request: ReviewsRequest) -> ReviewsResponse:
# ---> 10     return self._send_request(request)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\kinopoisk_unofficial\client\api_client.py:47, in ApiClient._send_request(self, request)
#      44     elif response.status_code == 429:
#      45         raise TooManyRequests()
# ---> 47 return self.__deserialize_response(
#      48     response.json(),
#      49     request.response_class()
#      50 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\kinopoisk_unofficial\client\api_client.py:57, in ApiClient.__deserialize_response(self, response_body, response_class)
#      52 def __deserialize_response(
#      53         self,
#      54         response_body: dict,
#      55         response_class: type
#      56 ) -> Response:
# ---> 57     return self.__serializer.deserialize(response_class, response_body)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\apischema\utils.py:546, in deprecate_kwargs.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     544         if replacement:
#     545             kwargs[replacement] = kwargs.get(replacement, arg)
# --> 546 return wrapped(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\apischema\deserialization\__init__.py:869, in deserialize(type, data, additional_properties, aliaser, coerce, conversion, default_conversion, fall_back_on_default, schema)
#     850 @deprecate_kwargs(
#     851     {
#     852         "coercion": "coerce",
#    (...)
#     867     schema: Schema = None,
#     868 ) -> Any:
# --> 869     return deserialization_method(
#     870         type,
#     871         additional_properties=additional_properties,
#     872         aliaser=aliaser,
#     873         coerce=coerce,
#     874         conversion=conversion,
#     875         default_conversion=default_conversion,
#     876         fall_back_on_default=fall_back_on_default,
#     877         schema=schema,
#     878     )(data)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\apischema\deserialization\__init__.py:528, in DeserializationMethodVisitor.object.<locals>.factory.<locals>.method(data)
#     526         raise error
#     527 elif field_errors or errors:
# --> 528     raise ValidationError(errors, field_errors)
#     529 else:
#     530     validators2, init = (), ...  # type: ignore # only for linter
#
# ValidationError: ValidationError(messages=[], children={'reviewAllPositiveRatio': ValidationError(messages=['expected type string, found null'], children={}), 'reviewPositiveCount': ValidationError(messages=['expected type integer, found null'], children={}), 'reviewNegativeCount': ValidationError(messages=['expected type integer, found null'], children={}), 'reviewNeutralCount': ValidationError(messages=['expected type integer, found null'], children={}), 'reviews': ValidationError(messages=(), children={0: ValidationError(messages=[], children={'userPositiveRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={}), 'userNegativeRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={})}), 1: ValidationError(messages=[], children={'userPositiveRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={}), 'userNegativeRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={})}), 2: ValidationError(messages=[], children={'userPositiveRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={}), 'userNegativeRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={})}), 3: ValidationError(messages=[], children={'userPositiveRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={}), 'userNegativeRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={})}), 4: ValidationError(messages=[], children={'userPositiveRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={}), 'userNegativeRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={})}), 5: ValidationError(messages=[], children={'userPositiveRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={}), 'userNegativeRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={})}), 6: ValidationError(messages=[], children={'userPositiveRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={}), 'userNegativeRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={})}), 7: ValidationError(messages=[], children={'userPositiveRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={}), 'userNegativeRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={})}), 8: ValidationError(messages=[], children={'userPositiveRating': ValidationError(messages=['expected type string, found integer', 'expected type null, found integer', 'expected type null, found integer'], children={}), 'userNegativeRating': ValidationError(messages=['expected type string, found integer', 'expected type n ...

# %%
response.film.
# Out:
# Film(kinopoisk_id=405609, imdb_id='tt1014759', name_ru='Алиса в Стране чудес', name_en=None, name_original='Alice in Wonderland', poster_url='https://kinopoiskapiunofficial.tech/images/posters/kp/405609.jpg', poster_url_preview='https://kinopoiskapiunofficial.tech/images/posters/kp_small/405609.jpg', reviews_count=0, rating_good_review=65.3, rating_good_review_vote_count=557, rating_kinopoisk=7.1, rating_kinopoisk_vote_count=313109, rating_imdb=6.4, rating_imdb_vote_count=417333, rating_film_critics=5.8, rating_film_critics_vote_count=278, rating_await=84.0, rating_await_count=45082, rating_rf_critics=29.0, rating_rf_critics_vote_count=7, year=2010, film_length=108, is_tickets_available=False, production_status=None, type=<FilmType.FILM: 'FILM'>, has_imax=True, has_3_d=True, countries=[Country(country='США')], genres=[Genre(genre='детектив'), Genre(genre='приключения'), Genre(genre='фэнтези'), Genre(genre='семейный')], start_year=None, end_year=None, cover_url='https://avatars.mds.yandex.net/get-ott/1531675/2a0000017c072e24f5a05d020f45fe24ec51/orig', logo_url='https://avatars.mds.yandex.net/get-ott/374297/2a0000016ef3b13e0d23da1eedf2c3904d77/orig', web_url='https://www.kinopoisk.ru/film/405609/', slogan='Вы приглашены на безумно важное событие', description='Жизнь 19-летней Алисы Кингсли принимает неожиданный оборот. На викторианской вечеринке, устроенной в её честь, Алисе делает предложение Хэмиш, богатый, но глупый сын лорда и леди Эскот. Не дав ответа, девушка убегает и идёт за кроликом, замеченным ею на лужайке. Кролик как кролик, вот только он одет в камзол и всё время смотрит на карманные часы.\n\nАлиса гонится за Белым Кроликом через весь луг и видит, как он исчезает в кроличьей норе. Затем, неожиданно, Алиса падает туда сама, летит вниз по странному, сказочному туннелю и приземляется в круглом зале со множеством дверей. Выпив из бутылки с надписью «ВЫПЕЙ МЕНЯ», она уменьшается в размерах, а откусив от пирожного с надписью «СЪЕШЬ МЕНЯ» — вырастает. Наконец, миновав череду злоключений, Алиса попадает через одну из дверей в чудесный фантастический мир, который его обитатели называют Подземной страной.\n\nТам её ждёт целый парад колоритных персонажей: хвастливая Соня, сумасшедший Шляпник, глумливый Чеширский Кот, накурившаяся кальяном гусеница по имени Абессалом, жутковатая Белая Королева и её злобная сестра, Королева Червей, вздорная и раздражительная правительница Подземной страны.', short_description='Своевольная девушка попадает в мир, где все с ног на голову. Льюис Кэрролл в интерпретации Тима Бёртона', editor_annotation=None, rating_mpaa='pg', rating_age_limits='age12', last_sync='2022-12-21T09:12:23.473061', serial=False, short_film=False, completed=False)
